# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
sns.set(style="whitegrid")

# %%
data = pd.read_csv("~/Desktop/python/CitiBikejan-may.csv")

# %%
data.head()
# Out:
#      Month  24-Hour Passes Purchased (midnight to 11:59 pm)  \
# 0  2019/01                                          21243.0
# 1  2019/02                                          25134.0
# 2  2019/03                                          58588.0
# 3  2019/04                                         122008.0
# 4  2019/05                                         161924.0
#
#    3-Day Passes Purchased (midnight to 11:59 pm)
# 0                                          579.0
# 1                                          711.0
# 2                                         1679.0
# 3                                         3289.0
# 4                                         4412.0

# %%
data.columns
# Out:
# Index(['Month', '24-Hour Passes Purchased (midnight to 11:59 pm)',
#        '3-Day Passes Purchased (midnight to 11:59 pm)'],
#       dtype='object')

# %%
sns.lineplot(data = data , x = "Month" , y = "24-Hour Passes Purchased (midnight to 11:59 pm)")

# %%
sns.lineplot(data = data , x = "Month" , y = "3-Day Passes Purchased (midnight to 11:59 pm)")

# %%
data_melt = data.melt(id_vars=["Month"], value_vars=["24-Hour Passes Purchased (midnight to 11:59 pm)","3-Day Passes Purchased (midnight to 11:59 pm)"])

# %%
data_melt.head()
# Out:
#      Month                                         variable     value
# 0  2019/01  24-Hour Passes Purchased (midnight to 11:59 pm)   21243.0
# 1  2019/02  24-Hour Passes Purchased (midnight to 11:59 pm)   25134.0
# 2  2019/03  24-Hour Passes Purchased (midnight to 11:59 pm)   58588.0
# 3  2019/04  24-Hour Passes Purchased (midnight to 11:59 pm)  122008.0
# 4  2019/05  24-Hour Passes Purchased (midnight to 11:59 pm)  161924.0

# %%
sns.lineplot(data = data_melt , x = "Month" , y = "value" , hue = "variable")
